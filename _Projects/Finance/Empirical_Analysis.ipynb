# %% [markdown]
# # Empirical Analysis
# ## Importing the Data
# We first retrieve the data from Quandl.

# %%
import pandas as pd
import os
import quandl
import time
import warnings
warnings.filterwarnings('ignore')

quandl_token = os.environ['QUANDL_TOKEN']

data = quandl.get("ECB/EURUSD", trim_start = "2018-01-01", trim_end = "2019-04-01", authtoken=quandl_token)

# %%
data.info()

data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 318 entries, 2018-01-02 to 2019-03-29
# Data columns (total 1 columns):
# Value    318 non-null float64
# dtypes: float64(1)
# memory usage: 5.0 KB
#              Value
# Date
# 2018-01-02  1.2065
# 2018-01-03  1.2023
# 2018-01-04  1.2065
# 2018-01-05  1.2045
# 2018-01-08  1.1973

# %% [markdown]
# ## Plotting the data

# %%
import matplotlib.pyplot as plt
plt.style.use('seaborn-deep')

data['Value'].plot(title="EUR/USD", figsize=(10,5))
plt.show()

# %% [markdown]
# ## First-order differencing

# %%
diff = data['Value'].diff()
diff.plot(title="EUR/USD", figsize=(10,5))
plt.show()

# %% [markdown]
# We can plot the distribution.

# %%
diff.plot(kind='kde')
plt.show()

# %% [markdown]
# ## Descriptive statistics

# %%
diff.describe()
# Out:
# count    317.000000
# mean      -0.000262
# std        0.005109
# min       -0.013700
# 25%       -0.003600
# 50%       -0.000500
# 75%        0.003000
# max        0.014500
# Name: Value, dtype: float64

# %% [markdown]
# ## Kurtosis

# %%
from scipy.stats import describe

diff.kurt()
# Out:
# -0.008590355846044062

# %% [markdown]
# ## Skewness

# %%
diff.skew()
# Out:
# 0.13925724694622255

# %% [markdown]
# ## Q-Q plot

# %%
from scipy.stats import probplot

stats.probplot(diff, dist="norm", plot=pylab)
pylab.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-c4df964f1425> in <module>()
#       1 from scipy.stats import probplot
#       2
# ----> 3 stats.probplot(diff, dist="norm", plot=pylab)
#       4 pylab.show()
#
# NameError: name 'stats' is not defined
